# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

import torch

import dask
import dask.array as da
import re
import glob
import os

from DWR_preprocess import *
import datetime

from tqdm import tqdm
from tqdm.contrib.itertools import product

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings("ignore")

station_number = 26061
window = 5

import sklearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split, KFold, \
    cross_val_score, RandomizedSearchCV, GridSearchCV, RepeatedKFold, \
    cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, \
                            precision_score, recall_score, confusion_matrix, \
                            ConfusionMatrixDisplay, roc_curve
from sklearn.feature_selection import SelectFromModel

import imblearn
from collections import Counter
 
window_shape = 5
station_number = 26061

# %% [markdown]
# ## processing

# %%
phen = get_npy_file(matched_list_phen)
# Out:
# (200, 200)

# %% [markdown]
# ## Stack analysis

# %%
stack = np.load(Paths.interim + f'stack_{station_number}.npy')
stack = np.delete(stack, (1,2), 0)
stack.shape
# Out:
# (7185, 200, 200, 18)

# %%
fig = plt.figure(figsize=(20,10))
# get the path of the file. It can be found in the repo data directory
img_extent = (26.625097804781607, 34.19102219521839,
              58.117582381530546, 61.72575761846945)

ax = plt.axes(projection=ccrs.NorthPolarStereo(central_longitude=30))
plt.title('Sum of thunderstrikes in cells by blitzortung.\n'
          '2020-2021')

ax.use_sticky_edges = False
# set a margin around the data
ax.set_xmargin(0.05)
ax.set_ymargin(0.10)

ax.set_extent([26.625097804781607-0.2, 34.19102219521839+0.2,
               58.117582381530546-0.2, 61.72575761846945+0.2],
              crs=ccrs.PlateCarree())


ax.add_feature(cfeature.OCEAN,facecolor=("lightblue"))
ax.coastlines(resolution='50m', color='black', linewidth=2)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAKES, facecolor='None',
               edgecolor='black', linewidth=2)

ax.gridlines(crs=ccrs.PlateCarree(), linewidth=2,
             color='black', alpha=0.5, linestyle='--',
             draw_labels=True)

plt.imshow(np.delete(np.sum(stack[:,:,:,-1], axis = 0),(0,-1),1),
           cmap = 'gist_ncar',
           origin='upper',
           extent=img_extent,
           transform=ccrs.PlateCarree())



plt.colorbar()#shrink = 0.5,aspect = 8)
plt.show()

# %%
phen = stack[:,:,:,12]
phen[phen != 26] = 0
phen[phen == 26] = 1

# %%
fig = plt.figure(figsize=(20,10))
# get the path of the file. It can be found in the repo data directory
img_extent = (26.625097804781607, 34.19102219521839,
              58.117582381530546, 61.72575761846945)

ax = plt.axes(projection=ccrs.NorthPolarStereo(central_longitude=30))
plt.title('Sum of thunderstrikes in cells by blitzortung.\n'
          '2020-2021')

ax.use_sticky_edges = False
# set a margin around the data
ax.set_xmargin(0.05)
ax.set_ymargin(0.10)

ax.set_extent([26.625097804781607-0.2, 34.19102219521839+0.2,
               58.117582381530546-0.2, 61.72575761846945+0.2],
              crs=ccrs.PlateCarree())


ax.add_feature(cfeature.OCEAN,facecolor=("lightblue"))
ax.coastlines(resolution='50m', color='black', linewidth=2)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAKES, facecolor='None',
               edgecolor='black', linewidth=2)

ax.gridlines(crs=ccrs.PlateCarree(), linewidth=2,
             color='black', alpha=0.5, linestyle='--',
             draw_labels=True)

plt.imshow(np.delete(np.sum(phen, axis = 0),(0,-1),1),
           cmap = 'gist_ncar',
           origin='upper',
           extent=img_extent,
           transform=ccrs.PlateCarree(),
           vmin=0, vmax=14)



plt.colorbar()#shrink = 0.5,aspect = 8)
plt.show()

# %%
stack = stack[:,10:190,10:190,:]

# %%
phen = stack[:,:,:,12]
phen[phen != 26] = 0
phen[phen == 26] = 1

# %%
scorer(stack[:,:,:,-1].flatten(), phen.flatten(), 'none', 5)
# Out:
# Accuracy is 0.9993
# f1_score is 0.1342
# precision_score is 0.1751
# recall_score is 0.1087
# roc_auc_score is 0.5873
# HSS is 0.1338
# ETS is 0.0717
# CSI is 0.0719
# sedi is 0.5807
# 0    0.999284
# 1    0.134163
# 2    0.175113
# 3    0.108736
# 4    0.587329
# 5    0.133825
# 6    0.071711
# 7    0.071905
# 8    0.580652
# dtype: float64

# %% [markdown]
# ## Filter analyzis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

import torch

import dask
import dask.array as da
import re
import glob
import os

from DWR_preprocess import *
import datetime

from tqdm import tqdm
from tqdm.contrib.itertools import product

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings("ignore")

station_number = 26061
window = 5

import sklearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split, KFold, \
    cross_val_score, RandomizedSearchCV, GridSearchCV, RepeatedKFold, \
    cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, \
                            precision_score, recall_score, confusion_matrix, \
                            ConfusionMatrixDisplay, roc_curve
from sklearn.feature_selection import SelectFromModel

import imblearn
from collections import Counter
 
window_shape = 5
station_number = 26061

# %%
df = pd.read_parquet(Paths.interim + f'{station_number}_Convective_cloud_windows_data.parquet')

# %%
# %%time
X = df.loc[:, df.columns != 'target']
y = df.loc[:, 'target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

#classificator 
sgd_clf = SGDClassifier(loss="log_loss", n_jobs = -1) 
sgd_clf.fit(X_train, y_train)
sgd_pred = sgd_clf.predict(X_test)

# get scores
sgd_res = scorer(y_test, sgd_pred, 'sgd', 5)
# Out:
# (2032605, 318) (508152, 318) (2032605,) (508152,)
# Accuracy is 0.9766
# f1_score is 0.5433
# precision_score is 0.4254
# recall_score is 0.7517
# roc_auc_score is 0.7103
# HSS is 0.5323
# ETS is 0.3627
# CSI is 0.373
# sedi is 0.8922
# CPU times: user 24.3 s, sys: 2.9 s, total: 27.2 s
# Wall time: 26.7 s

# %%
correlations = df.loc[:, df.columns != 'target'].corrwith(df['target'])
corr_sorted = correlations.sort_values(ascending=False)
pd.set_option('display.max_rows', None)
print(corr_sorted)
pd.set_option('display.max_rows', 25)
# Out:
# rmax_layer_11    0.542072
# R(1,3,11)        0.531138
# R(1,2,11)        0.530430
# R(2,3,11)        0.526862
# R(2,2,11)        0.526825
# R(0,3,11)        0.525262
# R(0,2,11)        0.524667
# R(1,4,11)        0.521915
# R(1,1,11)        0.519440
# R(2,4,11)        0.517063
# R(0,4,11)        0.516538
# R(2,1,11)        0.514862
# R(0,1,11)        0.514418
# R(3,3,11)        0.512196
# R(3,2,11)        0.510278
# R(1,2,10)        0.509047
# R(1,3,10)        0.508481
# R(3,4,11)        0.504738
# R(2,3,10)        0.504659
# R(2,2,10)        0.504543
# R(0,2,10)        0.504096
# R(0,3,10)        0.503853
# R(3,1,11)        0.500995
# R(1,4,10)        0.499837
# R(1,0,11)        0.499786
# R(1,1,10)        0.499388
# rmax_layer_10    0.498963
# R(0,0,11)        0.496425
# R(0,4,10)        0.496383
# R(2,4,10)        0.495853
# R(0,1,10)        0.495800
# R(2,0,11)        0.495660
# R(2,1,10)        0.494640
# R(3,3,10)        0.491239
# R(3,2,10)        0.490338
# R(4,3,11)        0.488436
# R(4,2,11)        0.486533
# R(3,4,10)        0.483931
# R(4,4,11)        0.483098
# R(3,0,11)        0.482374
# R(1,0,10)        0.481951
# R(3,1,10)        0.481499
# R(0,0,10)        0.478858
# R(4,1,11)        0.477694
# R(2,0,10)        0.477259
# R(4,3,10)        0.470908
# R(4,2,10)        0.469080
# R(1,2,9)         0.466284
# R(1,3,9)         0.465765
# R(4,4,10)        0.464849
# R(3,0,10)        0.464846
# R(2,3,9)         0.462323
# R(2,2,9)         0.462156
# R(4,0,11)        0.462095
# R(0,2,9)         0.461569
# R(0,3,9)         0.460910
# R(4,1,10)        0.460127
# R(1,1,9)         0.457700
# R(1,4,9)         0.457420
# R(2,4,9)         0.453854
# R(2,1,9)         0.453553
# R(0,4,9)         0.453495
# R(0,1,9)         0.453471
# R(3,3,9)         0.450494
# R(3,2,9)         0.449931
# R(4,0,10)        0.444974
# R(3,4,9)         0.442709
# R(3,1,9)         0.441488
# R(1,0,9)         0.440760
# R(0,0,9)         0.438245
# R(2,0,9)         0.436801
# hmax             0.434550
# rmax_layer_9     0.434529
# R(4,3,9)         0.430986
# R(4,2,9)         0.429770
# R(4,4,9)         0.425370
# R(3,0,9)         0.425268
# delta_iso22      0.422690
# R(4,1,9)         0.420855
# R(4,0,9)         0.406679
# R(1,2,8)         0.385589
# R(1,3,8)         0.384358
# R(2,2,8)         0.382883
# R(2,3,8)         0.382065
# R(0,2,8)         0.380581
# R(0,3,8)         0.379212
# R(1,1,8)         0.378722
# rmax             0.377231
# R(1,4,8)         0.376243
# R(2,1,8)         0.375769
# R(0,1,8)         0.374532
# R(2,4,8)         0.374225
# R(3,2,8)         0.372292
# R(3,3,8)         0.372242
# R(0,4,8)         0.371981
# R(3,4,8)         0.365165
# R(3,1,8)         0.365006
# R(1,0,8)         0.364670
# R(0,0,8)         0.361566
# R(2,0,8)         0.360924
# R(4,3,8)         0.356024
# R(4,2,8)         0.355097
# R(4,4,8)         0.350983
# R(3,0,8)         0.350839
# R(4,1,8)         0.347865
# rmax_layer_8     0.340070
# R(4,0,8)         0.335405
# H(1,2)           0.322061
# H(1,3)           0.321591
# H(2,2)           0.319441
# H(2,3)           0.319097
# H(0,2)           0.317884
# H(0,3)           0.317349
# H(1,1)           0.315845
# H(1,4)           0.314524
# H(2,1)           0.312954
# H(2,4)           0.312339
# H(0,1)           0.312072
# H(0,4)           0.310635
# H(3,3)           0.310202
# H(3,2)           0.310008
# H(3,4)           0.303850
# H(3,1)           0.303348
# H(1,0)           0.302604
# H(2,0)           0.299708
# H(0,0)           0.299613
# H(4,3)           0.295141
# H(4,2)           0.294179
# H(3,0)           0.290283
# R(1,2,7)         0.289728
# H(4,4)           0.289513
# R(1,3,7)         0.288333
# R(2,2,7)         0.287927
# H(4,1)           0.286990
# R(2,3,7)         0.286934
# R(0,2,7)         0.285451
# R(1,1,7)         0.284345
# R(0,3,7)         0.283709
# R(2,1,7)         0.282230
# R(1,4,7)         0.280605
# R(2,4,7)         0.280482
# R(0,1,7)         0.280421
# R(3,2,7)         0.279677
# R(3,3,7)         0.279119
# R(0,4,7)         0.276549
# H(4,0)           0.274769
# R(3,1,7)         0.273665
# R(3,4,7)         0.273112
# R(1,0,7)         0.272487
# R(2,0,7)         0.270078
# R(0,0,7)         0.269713
# R(4,3,7)         0.265867
# R(4,2,7)         0.265813
# R(3,0,7)         0.261860
# R(4,4,7)         0.261131
# R(4,1,7)         0.259916
# rmax_layer_7     0.252723
# R(4,0,7)         0.248912
# R(1,2,6)         0.211176
# R(2,2,6)         0.209687
# R(1,3,6)         0.209340
# R(2,3,6)         0.208458
# R(0,2,6)         0.206493
# R(1,1,6)         0.206180
# R(2,1,6)         0.204814
# R(0,3,6)         0.204771
# R(3,2,6)         0.202769
# R(3,3,6)         0.201989
# R(1,4,6)         0.201978
# R(2,4,6)         0.201977
# R(0,1,6)         0.201907
# R(0,4,6)         0.197793
# R(3,1,6)         0.197455
# R(3,4,6)         0.195808
# R(1,0,6)         0.195558
# rmax_layer_6     0.194512
# R(2,0,6)         0.193854
# R(0,0,6)         0.192480
# R(4,2,6)         0.190563
# R(4,3,6)         0.190563
# R(3,0,6)         0.186999
# R(4,4,6)         0.185165
# R(4,1,6)         0.185148
# R(4,0,6)         0.175374
# rmax_layer_5     0.164322
# R(1,2,5)         0.162361
# R(2,2,5)         0.161892
# R(1,3,5)         0.159900
# R(2,3,5)         0.159579
# R(1,1,5)         0.157921
# R(0,2,5)         0.156884
# R(2,1,5)         0.156865
# R(3,2,5)         0.155270
# R(0,3,5)         0.154813
# R(3,3,5)         0.153957
# R(0,1,5)         0.153075
# R(2,4,5)         0.151989
# R(1,4,5)         0.151923
# R(3,1,5)         0.150377
# R(1,0,5)         0.147375
# R(0,4,5)         0.147128
# R(3,4,5)         0.146581
# R(2,0,5)         0.146214
# R(0,0,5)         0.143576
# R(4,2,5)         0.143212
# R(4,3,5)         0.142501
# rmax_layer_4     0.142061
# R(3,0,5)         0.139593
# R(4,1,5)         0.138082
# R(4,4,5)         0.136366
# rmax_layer_1     0.129779
# R(1,2,4)         0.129117
# R(4,0,5)         0.128492
# R(2,2,4)         0.128386
# R(2,3,4)         0.125702
# R(1,3,4)         0.125570
# R(1,1,4)         0.125301
# R(2,1,4)         0.124613
# R(0,2,4)         0.123372
# R(3,2,4)         0.122058
# rmax_layer_3     0.121584
# R(3,3,4)         0.120687
# R(0,1,4)         0.120132
# R(0,3,4)         0.120125
# rmax_layer_2     0.119444
# R(3,1,4)         0.117509
# R(2,4,4)         0.116984
# R(1,4,4)         0.116637
# R(1,0,4)         0.115668
# R(2,0,4)         0.114109
# R(3,4,4)         0.112105
# R(1,2,3)         0.111999
# R(2,2,3)         0.111538
# R(0,0,4)         0.111319
# R(0,4,4)         0.111290
# R(4,2,4)         0.110322
# R(4,3,4)         0.109183
# R(1,1,3)         0.109172
# R(2,1,3)         0.108101
# R(2,3,3)         0.107914
# R(1,3,3)         0.107661
# R(3,0,4)         0.107488
# R(4,1,4)         0.105705
# R(0,2,3)         0.105614
# R(3,2,3)         0.105095
# R(0,1,3)         0.103585
# R(3,3,3)         0.102611
# R(4,4,4)         0.102205
# R(0,3,3)         0.100956
# R(3,1,3)         0.100956
# R(2,2,2)         0.100895
# R(1,2,2)         0.100530
# R(1,0,3)         0.099385
# R(1,1,2)         0.099373
# R(2,1,2)         0.098938
# R(2,4,3)         0.098538
# R(2,2,1)         0.098134
# R(1,2,1)         0.098008
# R(1,1,1)         0.097915
# R(2,0,3)         0.097696
# R(1,4,3)         0.097197
# R(2,1,1)         0.096954
# R(2,3,2)         0.096563
# R(4,0,4)         0.096006
# R(3,2,2)         0.095537
# R(1,3,2)         0.095377
# iso_22           0.095329
# R(0,0,3)         0.095152
# R(3,4,3)         0.093607
# R(4,2,3)         0.093404
# R(0,2,2)         0.093374
# R(0,1,2)         0.092629
# R(3,3,2)         0.092372
# R(2,3,1)         0.092345
# R(3,1,2)         0.092319
# R(3,2,1)         0.091859
# R(4,3,3)         0.091539
# R(1,3,1)         0.091154
# R(0,4,3)         0.090912
# R(3,0,3)         0.090825
# R(0,2,1)         0.090808
# R(0,1,1)         0.090732
# R(1,0,2)         0.089943
# R(2,0,2)         0.089589
# R(1,0,1)         0.089333
# R(3,1,1)         0.088880
# R(4,1,3)         0.088618
# R(3,3,1)         0.087968
# R(2,0,1)         0.087947
# R(0,3,2)         0.087504
# R(2,4,2)         0.086159
# R(0,0,2)         0.084459
# R(4,4,3)         0.084221
# R(1,4,2)         0.084143
# R(4,2,2)         0.084062
# R(0,3,1)         0.083912
# R(0,0,1)         0.083557
# R(3,0,2)         0.082514
# R(3,4,2)         0.082079
# R(4,3,2)         0.081656
# R(2,4,1)         0.081438
# R(3,0,1)         0.080760
# R(4,1,2)         0.080366
# R(1,4,1)         0.080035
# R(4,0,3)         0.079973
# R(4,2,1)         0.079717
# R(3,4,1)         0.078271
# R(4,3,1)         0.077448
# R(0,4,2)         0.076904
# R(4,1,1)         0.076683
# R(4,4,2)         0.073969
# R(0,4,1)         0.072620
# R(4,0,2)         0.071455
# R(4,4,1)         0.069428
# R(4,0,1)         0.069170
# y_coor           0.035869
# x_coor           0.009935
# date            -0.049378
# dtype: float64

# %%
true_index, = np.where(df.target == 1)
false_index, = np.where(df.target != 1)
print(f'0 - {false_index.shape}, 1 - {true_index.shape}')
# Out:
# 0 - (2457524,), 1 - (83233,)

# %%
df_true = df.iloc[true_index]
df_false = df.iloc[false_index]

# %%
df_filter_rmax = df_true[(df_true['rmax'] < 3.3)]
df_filter_hmax = df_true[(df_true['hmax'] < 4000)]
df_filter_delta = df_true[(df_true['delta_iso22'] < -2000)]

union = np.array(list(set(df_filter_rmax.index) | set(df_filter_hmax.index) | set(df_filter_delta.index)))
df_filtered_1 = df_true.loc[union]
df_filter_1 = df_true.loc[~df_true.index.isin(union)]
df_filtered_1['target'] = df_filtered_1['target'].replace(1,0)
df_false.shape, df_filter_1.shape, df_filtered_1.shape
# Out:
# ((2457524, 319), (82793, 319), (440, 319))

# %%
plot_6(df_true, 'Before any filtration')

# %%
plot_6(df_filter_1, 'After filtering')

# %%
plot_6(df_filtered_1, 'Filtered')

# %%
df = pd.concat((df_false, df_filter_1, df_filtered_1))

# %%
df_drop = df.drop(df[(df.x_coor > 190) | (df.y_coor > 190) | (df.x_coor < 10) | (df.y_coor < 10)].index)

# %%
# %%time
X = df_drop.loc[:, df_drop.columns != 'target']
y = df_drop.loc[:, 'target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)


#classificator 
sgd_clf = SGDClassifier(loss="log_loss", n_jobs = -1) 
sgd_clf.fit(X_train, y_train)
sgd_pred = sgd_clf.predict(X_test)

# get scores
sgd_res = scorer(y_test, sgd_pred, 'sgd', 5)
# Out:
# (1925554, 318) (481389, 318) (1925554,) (481389,)
# Accuracy is 0.9789
# f1_score is 0.6002
# precision_score is 0.5302
# recall_score is 0.6915
# roc_auc_score is 0.7614
# HSS is 0.5895
# ETS is 0.418
# CSI is 0.4287
# sedi is 0.8678
# CPU times: user 23.8 s, sys: 2.31 s, total: 26.1 s
# Wall time: 26 s

# %%
df_filter = pd.read_parquet(Paths.interim + f'df_filter_{station_number}.parquet')

# %%
sns.histplot(data = df_filter, x = 'rmax', hue = 'target', bins = np.arange(df_filter.rmax.min(),df_filter.rmax.max()))
plt.yscale('log')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

import torch

import dask
import dask.array as da
import re
import glob
import os

from DWR_preprocess import *
import datetime

from tqdm import tqdm
from tqdm.contrib.itertools import product

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import warnings
warnings.filterwarnings("ignore")

station_number = 26061
window = 5

import sklearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split, KFold, \
    cross_val_score, RandomizedSearchCV, GridSearchCV, RepeatedKFold, \
    cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, \
                            precision_score, recall_score, confusion_matrix, \
                            ConfusionMatrixDisplay, roc_curve
from sklearn.feature_selection import SelectFromModel

import imblearn
from collections import Counter
 
window_shape = 5
station_number = 26061

# %%
df = pd.read_parquet(Paths.interim + f"selected_df_{station_number}.parquet")

# %%
corr = df[['hmax', 'rmax', 'rmax_layer_5', 'rmax_layer_6',
       'rmax_layer_7', 'rmax_layer_8', 'rmax_layer_9', 'rmax_layer_10',
       'rmax_layer_11', 'target']].corr()
plt.figure(figsize=(9,9))
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot: >

# %%
X = df.loc[:, df.columns != 'target']
y = df.loc[:, 'target']

# %%
X = X.drop('delta_iso22', axis =1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1925554, 9) (481389, 9) (1925554,) (481389,)

# %%
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
print('Original dataset shape %s' % Counter(y.values.flatten().tolist()))
# Out:
# Original dataset shape Counter({0: 2335060, 1: 71883})

# %%
# %%time
#classificator 
sgd_clf = SGDClassifier(loss="log", n_jobs = -1) 
sgd_clf.fit(X_train, y_train)
sgd_pred = sgd_clf.predict(X_test)

# get scores
sgd_res = scorer(y_test, sgd_pred, 'sgd', 5)
# Out:
# Accuracy is 0.9783
# f1_score is 0.5706
# precision_score is 0.4827
# recall_score is 0.6976
# roc_auc_score is 0.7381
# HSS is 0.5599
# ETS is 0.3887
# CSI is 0.3992
# sedi is 0.8686
# CPU times: user 3.2 s, sys: 20.6 ms, total: 3.22 s
# Wall time: 3.22 s
